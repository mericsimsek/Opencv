# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
a=np.random.randint(1,100,20)
a.reshape(4,5)
# Out:
# array([[37, 22, 51, 44, 27],
#        [21, 17, 67, 67, 51],
#        [37, 17, 36, 67, 46],
#        [22, 88, 42, 91, 67]])

# %%
# !pip install opencv-python
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# %%
img=cv2.imread(r"C:\Users\meric\Desktop\Computer-Vision-with-Python\DATA\00-puppy.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img8=cv2.imread(r"C:\Users\meric\Desktop\Computer-Vision-with-Python\DATAdfgdfg\00-puppdfgy.jpg")
type(img8)
# Out:
# NoneType

# %%
#matplotlib  R G B
#opencv  B G R

# %%
fiximg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)#BGRDEN RGB ye dönütşürme işlemi

# %%
imggray=cv2.imread(r"C:\Users\meric\Desktop\Computer-Vision-with-Python\DATA\00-puppy.jpg",cv2.IMREAD_GRAYSCALE)

# %%
imggray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(imggray)

# %%
newsize=cv2.resize(fiximg,(3000,270))

# %%
plt.imshow(newsize)

# %%
heighs=0.5
widths=0.5
newsize=cv2.resize(fiximg,(0,0),fiximg,heighs,widths)

# %%
newsize.shape #yarıya düşürdük  mesela genişil 0.8 aslam %80 e düşürüyor olacağız  1.2 alsam %20 arttıracam
# Out:
# (650, 975, 3)

# %%
newsize=cv2.flip(fiximg,(-1))
plt.imshow(newsize)

# %%
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111)
ax.imshow(newsize)

# %%
fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
ax.imshow(fiximg)

# %%
cv2.imshow("Hello Meric",img)  #uygulama açar gibi başlığı hello meric olan fotoyu açıyor
cv2.waitKey()
# Out:
# -1

# %%
if cv2.waitKey(1) & 0xFF==27:
    break
    
cv2.destroyAllWindows()

# %%
imgs1=cv2.imread(r"C:\Users\meric\Desktop\Computer-Vision-with-Python\DATA\meric.jpg")

# %%
imgs1=cv2.resize(imgs1,(1300,550))

# %%
plt.imshow(imgs1)
